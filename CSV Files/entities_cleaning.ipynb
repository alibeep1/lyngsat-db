# %%
import numpy as np
import pandas as pd

# %%
channel_instances_df = pd.read_csv(f'E:/AUC/23-24/Spring/Database/Project/CSV Files/entities/channel_instances.csv')

# %%
# channel_instances_df.shape

# %%
channel_instances_df.drop_duplicates(subset=['Channel','Sattelite_Name', 'freq_alt'], inplace=True)

# %%
# channel_instances_df[['Sattelite_Name','Provider/Channel','Provider','FEC']][51:100]

# vals = channel_instances_df['FEC'].value_counts()

# %%
channel_instances_df[~channel_instances_df['FEC'].astype(str).str.contains('^\d')]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Ali\AppData\Local\Temp\ipykernel_2824\3573765530.py:1: SyntaxWarning: invalid escape sequence '\d'
#   channel_instances_df[~channel_instances_df['FEC'].astype(str).str.contains('^\d')]
#       Sattelite_Name Provider           Provider/Channel  \
# 110    Eutelsat-172B      NaN  NBC TV (Papua New Guinea)
# 114    Eutelsat-172B      NaN   EM TV (Papua New Guinea)
# 115    Eutelsat-172B      NaN                       CGTN
# 116    Eutelsat-172B      NaN                Pasifika TV
# 117    Eutelsat-172B      NaN                CGTN Arabic
# ...              ...      ...                        ...
# 18936      Galaxy-30      GCI                   FXX East
# 18938      Galaxy-30      GCI                    FX West
# 18940      Galaxy-30      GCI   National Geographic West
# 18942      Galaxy-30      GCI   National Geographic Wild
# ...
